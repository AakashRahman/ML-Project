# %%
import pandas as pd
#import sportsreference as sportsreference
from pprint import pprint
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.postgresql:postgresql:42.1.1 pyspark-shell'
# Find the latest version of spark 3.0  from http://www-us.apache.org/dist/spark/ and enter as the spark version
# For example:
#spark_version = 'spark-3.0.1'
#os.environ['SPARK_VERSION']=spark_version

# # Install Spark and Java
# #!apt-get update
# #!apt-get install openjdk-11-jdk-headless -qq > /dev/null
# #!wget -q http://www-us.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
# os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
# import findspark
# findspark.init()
# Out:
# Requirement already up-to-date: sklearn in /opt/anaconda3/lib/python3.7/site-packages (0.0)
# ...

# %%
from sportsreference.nfl.teams import Teams

df=pd.DataFrame()   
teams = []
years = []
for i in range(2002, 2020):
    
    teams = Teams(i)
    for team in teams:
        df = df.append(team.dataframe)
        years.append(i)
    
df["years"]=years
df
# Out:
#     abbreviation  defensive_simple_rating_system  first_downs  \
# KAN          KAN                            -2.3          343
# RAI          RAI                             4.3          366
# NOR          NOR                            -3.3          291
# PHI          PHI                             3.8          311
# ATL          ATL                             1.5          316
# ..           ...                             ...          ...
# DEN          DEN                             2.7          279
# CHI          CHI                             4.5          297
# CIN          CIN                            -2.9          312
# NYJ          NYJ                            -0.6          253
# WAS          WAS                            -4.5          248
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# KAN                          24        2            16             13       8
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# abbreviation
# defensive_simple_rating_system
# first_downs
# first_downs_from_penalties
# fumbles
# games_played
# interceptions
# losses
# margin_of_victory
# name
# offensive_simple_rating_system
# pass_attempts
# pass_completions
# pass_first_downs
# pass_net_yards_per_attempt
# pass_touchdowns
# pass_yards
# penalties
# percent_drives_with_points
# percent_drives_with_turnovers
# plays
# points_against
# points_contributed_by_offense
# points_difference
# points_for
# post_season_result
# rank
# rush_attempts
# rush_first_downs
# rush_touchdowns
# rush_yards
# rush_yards_per_attempt
# simple_rating_system
# strength_of_schedule
# turnovers
# win_percentage
# wins
# yards
# yards_from_penalties
# yards_per_play
# years

# %%
#offense only df
Offense_df = df[['years', 'abbreviation', 'yards', 'margin_of_victory', 'offensive_simple_rating_system', 'pass_attempts', 'pass_completions', 'pass_first_downs', 'pass_net_yards_per_attempt', 'pass_touchdowns', 'pass_yards', 'percent_drives_with_turnovers', 'percent_drives_with_points', 'plays', 'points_contributed_by_offense', 'rank', 'rush_attempts', 'rush_first_downs','rush_yards','rush_yards_per_attempt', 'turnovers', 'win_percentage', 'yards_per_play', 'first_downs']]
Offense_df.columns
# Out:
# Index(['years', 'abbreviation', 'yards', 'margin_of_victory',
#        'offensive_simple_rating_system', 'pass_attempts', 'pass_completions',
#        'pass_first_downs', 'pass_net_yards_per_attempt', 'pass_touchdowns',
#        'pass_yards', 'percent_drives_with_turnovers',
#        'percent_drives_with_points', 'plays', 'points_contributed_by_offense',
#        'rank', 'rush_attempts', 'rush_first_downs', 'rush_yards',
#        'rush_yards_per_attempt', 'turnovers', 'win_percentage',
#        'yards_per_play', 'first_downs'],
#       dtype='object')

# %%
#defense only df
Defense_df = df[['years', 'abbreviation', 'defensive_simple_rating_system', 'interceptions', 'points_against']]
Defense_df
# Out:
#      years abbreviation  defensive_simple_rating_system  interceptions  \
# KAN   2002          KAN                            -2.3             13
# RAI   2002          RAI                             4.3             10
# NOR   2002          NOR                            -3.3             15
# PHI   2002          PHI                             3.8             11
# ATL   2002          ATL                             1.5             12
# ..     ...          ...                             ...            ...
# DEN   2019          DEN                             2.7             10
# CHI   2019          CHI                             4.5             12
# CIN   2019          CIN                            -2.9             16
# NYJ   2019          NYJ                            -0.6             16
# WAS   2019          WAS                            -4.5             13
#
#      points_against
# KAN             399
# RAI             304
# NOR             388
# PHI             241
# ...

# %%
#misc df
Misc_df = df[['years', 'abbreviation', 'fumbles', 'games_played', 'losses', 'name', 'first_downs_from_penalties', 'penalties', 'points_difference', 'points_for', 'post_season_result', 'simple_rating_system', 'strength_of_schedule', 'win_percentage', 'wins', 'yards_from_penalties']]
Misc_df
# Out:
#      years abbreviation  fumbles  games_played  losses                 name  \
# KAN   2002          KAN        2            16       8   Kansas City Chiefs
# RAI   2002          RAI        9            16       5      Oakland Raiders
# NOR   2002          NOR       15            16       7   New Orleans Saints
# PHI   2002          PHI       13            16       4  Philadelphia Eagles
# ATL   2002          ATL       15            16       6      Atlanta Falcons
# ..     ...          ...      ...           ...     ...                  ...
# DEN   2019          DEN        6            16       9       Denver Broncos
# CHI   2019          CHI        7            16       8        Chicago Bears
# CIN   2019          CIN       14            16      14   Cincinnati Bengals
# NYJ   2019          NYJ        9            16       9        New York Jets
# WAS   2019          WAS        8            16      13  Washington Redskins
#
# ...

# %%
Offense_df.to_csv("offense.csv", index=False, header=True)
Defense_df.to_csv("defense.csv", index=False, header=True)
Misc_df.to_csv("misc.csv", index=False, header=True)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("CloudETL").config("spark.driver.extraClassPath","/content/postgresql-42.2.9.jar").getOrCreate()

# %%
# Read in data from S3 Buckets
from pyspark import SparkFiles
url="https://nfl-guyz.s3.amazonaws.com/offense.csv"
spark.sparkContext.addFile(url)
offense_data_df = spark.read.csv(SparkFiles.get("offense.csv"), sep=",", header=True, inferSchema=True)
#defense_data_df = spark.read.csv(SparkFiles.get("defense.csv"), sep=",", header=True, inferSchema=True)
#misc_data_df = spark.read.csv(SparkFiles.get("misc.csv"), sep=",", header=True, inferSchema=True)

# %%
url="https://nfl-guyz.s3.amazonaws.com/defense.csv"
spark.sparkContext.addFile(url)
defense_data_df = spark.read.csv(SparkFiles.get("defense.csv"), sep=",", header=True, inferSchema=True)

# %%
url="https://nfl-guyz.s3.amazonaws.com/misc.csv"
spark.sparkContext.addFile(url)
misc_data_df = spark.read.csv(SparkFiles.get("misc.csv"), sep=",", header=True, inferSchema=True)

# %%
# Out:
# +-----+------------+-----+-----------------+------------------------------+-------------+----------------+----------------+--------------------------+---------------+----------+-----------------------------+--------------------------+-----+-----------------------------+----+-------------+----------------+----------------------+---------+--------------+--------------+-----------+
# |years|abbreviation|yards|margin_of_victory|offensive_simple_rating_system|pass_attempts|pass_completions|pass_first_downs|pass_net_yards_per_attempt|pass_touchdowns|pass_yards|percent_drives_with_turnovers|percent_drives_with_points|plays|points_contributed_by_offense|rank|rush_attempts|rush_first_downs|rush_yards_per_attempt|turnovers|win_percentage|yards_per_play|first_downs|
# ...

# %%
mode = "append"
jdbc_url="jdbc:postgresql://db-inst-on-aws.cve4fghw24yv.us-east-2.rds.amazonaws.com:5432/nfl-final-project"
config = {"user":"root", 
          "password": "password", 
          "driver":"org.postgresql.Driver"}

# %%
offense_data_df.write.jdbc(url=jdbc_url, table='offense', mode=mode, properties=config)
defense_data_df.write.jdbc(url=jdbc_url, table='defense', mode=mode, properties=config)
misc_data_df.write.jdbc(url=jdbc_url, table='misc', mode=mode, properties=config)
#sqlContext.read.format("jdbc").option(url).option("offense").load()

# %%
offense = Offense_df.to_dict('records')
defense = Defense_df.to_dict('records')
misc = Misc_df.to_dict('record')

# %%
# Set features. This will also be used as your x values.
target = df["wins"]
data = df.drop("wins", axis=1)
feature_names = data.columns
data.head()
# Out:
#     abbreviation  defensive_simple_rating_system  first_downs  \
# KAN          KAN                            -2.3          343
# RAI          RAI                             4.3          366
# NOR          NOR                            -3.3          291
# PHI          PHI                             3.8          311
# ATL          ATL                             1.5          316
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# KAN                          24        2            16             13       8
# RAI                          27        9            16             10       5
# NOR                          31       15            16             15       7
# PHI                          23       13            16             11       4
# ATL                          30       15            16             12       6
#
#      margin_of_victory                 name  ...  rush_yards  \
# ...

# %%
y = df["wins"]
X = df.drop(columns=["wins", "abbreviation", "name", "post_season_result", "win_percentage", "losses", "margin_of_victory", "points_difference", "simple_rating_system", "games_played", "offensive_simple_rating_system", "points_for", "defensive_simple_rating_system", "points_contributed_by_offense", "points_against", "rank", "percent_drives_with_points", "strength_of_schedule", "years"])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=90)

# %%
X_train.head()
# Out:
#      first_downs  first_downs_from_penalties  fumbles  interceptions  \
# TAM          288                          19       13              6
# DET          290                          29       17             22
# DEN          357                          33        7             20
# SEA          328                          24        7              7
# KAN          256                          26       10             17
#
#      pass_attempts  pass_completions  pass_first_downs  \
# TAM            494               306               172
# DET            596               372               208
# DEN            554               359               199
# SEA            454               287               160
# KAN            536               296               139
#
#      pass_net_yards_per_attempt  pass_touchdowns  pass_yards  ...  plays  \
# TAM                         6.4               26        3361  ...    955
# ...

# %%
# Pre-processing
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.39754098, 0.24390244, 0.45833333, ..., 0.45873911, 0.43978495,
#         0.6       ],
#        [0.4057377 , 0.48780488, 0.625     , ..., 0.35289595, 0.54946237,
#         0.43333333],
#        [0.68032787, 0.58536585, 0.20833333, ..., 0.6453101 , 0.4827957 ,
#         0.66666667],
#        ...,
#        [0.30327869, 0.82926829, 0.375     , ..., 0.21937468, 0.5       ,
#         0.3       ],
#        [0.68442623, 0.3902439 , 0.29166667, ..., 0.62916453, 0.48494624,
#         0.73333333],
#        [0.6147541 , 0.41463415, 0.16666667, ..., 0.65581753, 0.59892473,
#         0.8       ]])

# %%
# Model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {rf.score(X_train, y_train)}")
print(f"Testing Data Score: {rf.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.1875

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.05689493739443026, 'pass_first_downs'),
#  (0.056746229162136064, 'pass_attempts'),
#  (0.051244680821122775, 'losses'),
#  (0.049543672716262276, 'pass_yards'),
#  (0.049255695565498615, 'plays'),
#  (0.04795910497289248, 'abbreviation'),
#  (0.047700345374861286, 'pass_touchdowns'),
#  (0.0468875226669652, 'percent_drives_with_turnovers'),
#  (0.046700500309124766, 'defensive_simple_rating_system'),
#  (0.0451430882845891, 'first_downs_from_penalties'),
#  (0.045036139374794414, 'pass_completions'),
#  (0.04475124442227407, 'margin_of_victory'),
#  (0.04467701106554441, 'offensive_simple_rating_system'),
#  (0.04353165621236246, 'pass_net_yards_per_attempt'),
#  (0.04345099186330564, 'penalties'),
#  (0.043257283575246525, 'percent_drives_with_points'),
#  (0.04293342115979463, 'games_played'),
#  (0.04153848745209664, 'fumbles'),
#  (0.04065946454749555, 'interceptions'),
#  (0.040603851405752046, 'name'),
#  (0.03599311585776204, 'points_against'),
# ...

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [250, 300, 350],
              'max_depth': [125, 150, 175]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=125, n_estimators=250 .................................
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... max_depth=125, n_estimators=250, score=0.149, total=   1.3s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.149, total=   1.4s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.7s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.198, total=   1.3s
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 175, 'n_estimators': 350}
# 0.2246992782678428

# %%
# Training score:
grid.score(X_train, y_train)
# Out:
# 1.0

# %%
# Testing score:
grid.score(X_test, y_test)
# Out:
# 0.18055555555555555

# %%
# Make prediction and save to variable for report.
predictions = grid.predict(X_test)

# %%
# Print Classification Report.
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         4
#            3       0.00      0.00      0.00         3
#            4       0.31      0.29      0.30        14
#            5       0.25      0.13      0.17        15
#            6       0.15      0.22      0.18         9
#            7       0.10      0.30      0.15        10
#            8       0.08      0.06      0.07        16
#            9       0.20      0.18      0.19        17
#           10       0.21      0.38      0.27        16
#           11       0.14      0.06      0.09        16
#           12       0.38      0.27      0.32        11
#           13       0.11      0.11      0.11         9
#           14       0.00      0.00      0.00         1
#           15       0.00      0.00      0.00         1
#
#     accuracy                           0.18       144
# ...

# %%
# %matplotlib notebook
from yellowbrick.classifier import ClassificationReport
viz = ClassificationReport(RandomForestClassifier())
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.finalize()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-7c97d1d1afe0> in <module>
#       1 # %matplotlib notebook
# ----> 2 from yellowbrick.classifier import ClassificationReport
#       3 viz = ClassificationReport(RandomForestClassifier())
#       4 viz.fit(X_train, y_train)
#       5 viz.score(X_test, y_test)
#
# ModuleNotFoundError: No module named 'yellowbrick'

# %%
from yellowbrick.model_selection import FeatureImportances
from yellowbrick.style import set_palette
from yellowbrick.features import RadViz
set_palette('yellowbrick')
viz = FeatureImportances(rf, size=(500, 500))
viz.fit(X_train, y_train)

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'randomforest.sav'
joblib.dump(rf, 'randomforest.sav')
