# %%
import pandas as pd
import sportsreference as sportsreference
from pprint import pprint
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already up-to-date: sklearn in c:\users\treyg\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\treyg\anaconda3\lib\site-packages (from sklearn) (0.22.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\treyg\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\treyg\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\treyg\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.1)
# Requirement already satisfied: joblib in c:\users\treyg\anaconda3\lib\site-packages (0.14.1)

# %%
from sportsreference.nfl.teams import Teams

df=pd.DataFrame()   
teams = []
years = []
for i in range(2002, 2020):
    
    teams = Teams(i)
    for team in teams:
        df = df.append(team.dataframe)
        years.append(i)
    
df["years"]=years
df
# Out:
#     abbreviation  defensive_simple_rating_system  first_downs  \
# KAN          KAN                            -2.3          343
# RAI          RAI                             4.3          366
# NOR          NOR                            -3.3          291
# PHI          PHI                             3.8          311
# ATL          ATL                             1.5          316
# ..           ...                             ...          ...
# DEN          DEN                             2.7          279
# CHI          CHI                             4.5          297
# CIN          CIN                            -2.9          312
# NYJ          NYJ                            -0.6          253
# WAS          WAS                            -4.5          248
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# KAN                          24        2            16             13       8
# RAI                          27        9            16             10       5
# NOR                          31       15            16             15       7
# PHI                          23       13            16             11       4
# ATL                          30       15            16             12       6
# ..                          ...      ...           ...            ...     ...
# DEN                          40        6            16             10       9
# CHI                          34        7            16             12       8
# CIN                          36       14            16             16      14
# NYJ                          30        9            16             16       9
# WAS                          20        8            16             13      13
#
#      margin_of_victory                 name  ...  rush_yards_per_attempt  \
# KAN                4.3   Kansas City Chiefs  ...                     5.1
# RAI                9.1      Oakland Raiders  ...                     4.3
# NOR                2.8   New Orleans Saints  ...                     4.1
# PHI               10.9  Philadelphia Eagles  ...                     4.5
# ATL                5.5      Atlanta Falcons  ...                     4.5
# ..                 ...                  ...  ...                     ...
# DEN               -2.1       Denver Broncos  ...                     4.1
# CHI               -1.1        Chicago Bears  ...                     3.7
# CIN               -8.8   Cincinnati Bengals  ...                     3.9
# NYJ               -5.2        New York Jets  ...                     3.3
# WAS              -10.6  Washington Redskins  ...                     4.4
#
#      simple_rating_system  strength_of_schedule  turnovers  win_percentage  \
# KAN                   6.1                   1.9         15           0.500
# RAI                  10.6                   1.5         19           0.688
# NOR                   2.4                  -0.3         30           0.563
# PHI                   8.3                  -2.6         24           0.750
# ATL                   5.1                  -0.4         27           0.594
# ..                    ...                   ...        ...             ...
# DEN                  -2.1                   0.0         16           0.438
# CHI                  -0.9                   0.2         19           0.500
# CIN                  -7.3                   1.5         30           0.125
# NYJ                  -6.3                  -1.1         25           0.438
# WAS                 -10.8                  -0.2         21           0.188
#
#      wins  yards  yards_from_penalties  yards_per_play  years
# KAN     8   6000                   700             6.2   2002
# RAI    11   6237                  1094             5.8   2002
# NOR     9   5205                   911             5.2   2002
# PHI    12   5604                   897             5.2   2002
# ATL     9   5535                   931             5.3   2002
# ..    ...    ...                   ...             ...    ...
# DEN     7   4777                   912             5.0   2019
# CHI     8   4749                   838             4.7   2019
# CIN     2   5169                   761             4.9   2019
# NYJ     7   4368                  1105             4.6   2019
# WAS     3   4395                   835             5.0   2019
#
# [576 rows x 41 columns]

# %%
for col in df.columns:
    print(col)
# Out:
# abbreviation
# defensive_simple_rating_system
# first_downs
# first_downs_from_penalties
# fumbles
# games_played
# interceptions
# losses
# margin_of_victory
# name
# offensive_simple_rating_system
# pass_attempts
# pass_completions
# pass_first_downs
# pass_net_yards_per_attempt
# pass_touchdowns
# pass_yards
# penalties
# percent_drives_with_points
# percent_drives_with_turnovers
# plays
# points_against
# points_contributed_by_offense
# points_difference
# points_for
# post_season_result
# rank
# rush_attempts
# rush_first_downs
# rush_touchdowns
# rush_yards
# rush_yards_per_attempt
# simple_rating_system
# strength_of_schedule
# turnovers
# win_percentage
# wins
# yards
# yards_from_penalties
# yards_per_play
# years

# %%
#offense only df
Offense_df = df[['years', 'abbreviation', 'yards', 'margin_of_victory', 'offensive_simple_rating_system', 'pass_attempts', 'pass_completions', 'pass_first_downs', 'pass_net_yards_per_attempt', 'pass_touchdowns', 'pass_yards', 'percent_drives_with_turnovers', 'percent_drives_with_points', 'plays', 'points_contributed_by_offense', 'rank', 'rush_attempts', 'rush_first_downs', 'rush_yards_per_attempt', 'turnovers', 'win_percentage', 'yards_per_play', 'first_downs']]
Offense_df
# Out:
#      years abbreviation  yards  margin_of_victory  \
# KAN   2002          KAN   6000                4.3
# RAI   2002          RAI   6237                9.1
# NOR   2002          NOR   5205                2.8
# PHI   2002          PHI   5604               10.9
# ATL   2002          ATL   5535                5.5
# ..     ...          ...    ...                ...
# DEN   2019          DEN   4777               -2.1
# CHI   2019          CHI   4749               -1.1
# CIN   2019          CIN   5169               -8.8
# NYJ   2019          NYJ   4368               -5.2
# WAS   2019          WAS   4395              -10.6
#
#      offensive_simple_rating_system  pass_attempts  pass_completions  \
# KAN                             8.4            477               292
# RAI                             6.3            619               418
# NOR                             5.8            538               291
# PHI                             4.5            548               318
# ATL                             3.5            479               268
# ..                              ...            ...               ...
# DEN                            -4.8            504               312
# CHI                            -5.4            580               371
# CIN                            -4.4            616               356
# NYJ                            -5.7            521               323
# WAS                            -6.3            479               298
#
#      pass_first_downs  pass_net_yards_per_attempt  pass_touchdowns  ...  \
# KAN               179                         7.2               27  ...
# RAI               226                         6.8               26  ...
# NOR               169                         6.0               27  ...
# PHI               164                         5.8               27  ...
# ATL               163                         6.1               18  ...
# ..                ...                         ...              ...  ...
# DEN               162                         5.7               16  ...
# CHI               178                         5.3               20  ...
# CIN               191                         5.5               18  ...
# NYJ               162                         5.4               19  ...
# WAS               154                         5.3               18  ...
#
#      plays  points_contributed_by_offense  rank  rush_attempts  \
# KAN    965                         145.45     1            462
# RAI   1069                         123.35     2            414
# NOR   1001                         -77.44     3            426
# PHI   1073                         -15.34     4            489
# ATL   1038                          38.40     5            523
# ..     ...                            ...   ...            ...
# DEN    954                         -14.61    28            409
# CHI   1020                         -41.05    29            395
# CIN   1049                         -60.73    30            385
# NYJ    956                        -112.92    31            383
# WAS    885                         -88.30    32            356
#
#      rush_first_downs  rush_yards_per_attempt  turnovers  win_percentage  \
# KAN               140                     5.1         15           0.500
# RAI               113                     4.3         19           0.688
# NOR                91                     4.1         30           0.563
# PHI               124                     4.5         24           0.750
# ATL               123                     4.5         27           0.594
# ..                ...                     ...        ...             ...
# DEN                77                     4.1         16           0.438
# CHI                85                     3.7         19           0.500
# CIN                85                     3.9         30           0.125
# NYJ                61                     3.3         25           0.438
# WAS                74                     4.4         21           0.188
#
#      yards_per_play  first_downs
# KAN             6.2          343
# RAI             5.8          366
# NOR             5.2          291
# PHI             5.2          311
# ATL             5.3          316
# ..              ...          ...
# DEN             5.0          279
# CHI             4.7          297
# CIN             4.9          312
# NYJ             4.6          253
# WAS             5.0          248
#
# [576 rows x 23 columns]

# %%
#defense only df
Defense_df = df[['years', 'abbreviation', 'defensive_simple_rating_system', 'interceptions', 'points_against']]
Defense_df
# Out:
#      years abbreviation  defensive_simple_rating_system  interceptions  \
# KAN   2002          KAN                            -2.3             13
# RAI   2002          RAI                             4.3             10
# NOR   2002          NOR                            -3.3             15
# PHI   2002          PHI                             3.8             11
# ATL   2002          ATL                             1.5             12
# ..     ...          ...                             ...            ...
# DEN   2019          DEN                             2.7             10
# CHI   2019          CHI                             4.5             12
# CIN   2019          CIN                            -2.9             16
# NYJ   2019          NYJ                            -0.6             16
# WAS   2019          WAS                            -4.5             13
#
#      points_against
# KAN             399
# RAI             304
# NOR             388
# PHI             241
# ATL             314
# ..              ...
# DEN             316
# CHI             298
# CIN             420
# NYJ             359
# WAS             435
#
# [576 rows x 5 columns]

# %%
#misc df
Misc_df = df[['years', 'abbreviation', 'fumbles', 'games_played', 'losses', 'name', 'first_downs_from_penalties', 'penalties', 'points_difference', 'points_for', 'post_season_result', 'simple_rating_system', 'strength_of_schedule', 'win_percentage', 'wins', 'yards_from_penalties']]
Misc_df
# Out:
#      years abbreviation  fumbles  games_played  losses                 name  \
# KAN   2002          KAN        2            16       8   Kansas City Chiefs
# RAI   2002          RAI        9            16       5      Oakland Raiders
# NOR   2002          NOR       15            16       7   New Orleans Saints
# PHI   2002          PHI       13            16       4  Philadelphia Eagles
# ATL   2002          ATL       15            16       6      Atlanta Falcons
# ..     ...          ...      ...           ...     ...                  ...
# DEN   2019          DEN        6            16       9       Denver Broncos
# CHI   2019          CHI        7            16       8        Chicago Bears
# CIN   2019          CIN       14            16      14   Cincinnati Bengals
# NYJ   2019          NYJ        9            16       9        New York Jets
# WAS   2019          WAS        8            16      13  Washington Redskins
#
#      first_downs_from_penalties  penalties  points_difference  points_for  \
# KAN                          24         75                 68         467
# RAI                          27        129                146         450
# NOR                          31        119                 44         432
# PHI                          23        111                174         415
# ATL                          30        105                 88         402
# ..                          ...        ...                ...         ...
# DEN                          40        110                -34         282
# CHI                          34        103                -18         280
# CIN                          36         93               -141         279
# NYJ                          30        115                -83         276
# WAS                          20        106               -169         266
#
#                post_season_result  simple_rating_system  strength_of_schedule  \
# KAN                          None                   6.1                   1.9
# RAI  Lost Conference Championship                  10.6                   1.5
# NOR                          None                   2.4                  -0.3
# PHI  Lost Conference Championship                   8.3                  -2.6
# ATL               Lost Divisional                   5.1                  -0.4
# ..                            ...                   ...                   ...
# DEN                          None                  -2.1                   0.0
# CHI                          None                  -0.9                   0.2
# CIN                          None                  -7.3                   1.5
# NYJ                          None                  -6.3                  -1.1
# WAS                          None                 -10.8                  -0.2
#
#      win_percentage  wins  yards_from_penalties
# KAN           0.500     8                   700
# RAI           0.688    11                  1094
# NOR           0.563     9                   911
# PHI           0.750    12                   897
# ATL           0.594     9                   931
# ..              ...   ...                   ...
# DEN           0.438     7                   912
# CHI           0.500     8                   838
# CIN           0.125     2                   761
# NYJ           0.438     7                  1105
# WAS           0.188     3                   835
#
# [576 rows x 16 columns]

# %%
offense = Offense_df.to_dict('records')
defense = Defense_df.to_dict('records')
misc = Misc_df.to_dict('record')

# %%
# Set features. This will also be used as your x values.
target = df["wins"]
data = df.drop("wins", axis=1)
feature_names = data.columns
data.head()
# Out:
#     abbreviation  defensive_simple_rating_system  first_downs  \
# KAN          KAN                            -2.3          343
# RAI          RAI                             4.3          366
# NOR          NOR                            -3.3          291
# PHI          PHI                             3.8          311
# ATL          ATL                             1.5          316
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# KAN                          24        2            16             13       8
# RAI                          27        9            16             10       5
# NOR                          31       15            16             15       7
# PHI                          23       13            16             11       4
# ATL                          30       15            16             12       6
#
#      margin_of_victory                 name  ...  rush_yards  \
# KAN                4.3   Kansas City Chiefs  ...        2378
# RAI                9.1      Oakland Raiders  ...        1762
# NOR                2.8   New Orleans Saints  ...        1764
# PHI               10.9  Philadelphia Eagles  ...        2220
# ATL                5.5      Atlanta Falcons  ...        2368
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# KAN                     5.1                   6.1                   1.9
# RAI                     4.3                  10.6                   1.5
# NOR                     4.1                   2.4                  -0.3
# PHI                     4.5                   8.3                  -2.6
# ATL                     4.5                   5.1                  -0.4
#
#      turnovers  win_percentage  yards  yards_from_penalties  yards_per_play  \
# KAN         15           0.500   6000                   700             6.2
# RAI         19           0.688   6237                  1094             5.8
# NOR         30           0.563   5205                   911             5.2
# PHI         24           0.750   5604                   897             5.2
# ATL         27           0.594   5535                   931             5.3
#
#      years
# KAN   2002
# RAI   2002
# NOR   2002
# PHI   2002
# ATL   2002
#
# [5 rows x 40 columns]

# %%
y = df["wins"]
X = df.drop(columns=["wins", "abbreviation", "name", "post_season_result", "win_percentage", "losses", "margin_of_victory", "points_difference", "simple_rating_system", "games_played", "offensive_simple_rating_system", "points_for", "defensive_simple_rating_system", "points_contributed_by_offense", "points_against", "rank", "percent_drives_with_points", "strength_of_schedule", "years"])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=90)

# %%
X_train.head()
# Out:
#      first_downs  first_downs_from_penalties  fumbles  interceptions  \
# TAM          288                          19       13              6
# DET          290                          29       17             22
# DEN          357                          33        7             20
# SEA          328                          24        7              7
# KAN          256                          26       10             17
#
#      pass_attempts  pass_completions  pass_first_downs  \
# TAM            494               306               172
# DET            596               372               208
# DEN            554               359               199
# SEA            454               287               160
# KAN            536               296               139
#
#      pass_net_yards_per_attempt  pass_touchdowns  pass_yards  ...  plays  \
# TAM                         6.4               26        3361  ...    955
# DET                         5.8               21        3820  ...    963
# DEN                         6.4               21        3824  ...   1057
# SEA                         6.6               20        3250  ...   1021
# KAN                         5.0               18        2922  ...   1019
#
#      rush_attempts  rush_first_downs  rush_touchdowns  rush_yards  \
# TAM            431                97                9        2001
# DET            304                53                9        1129
# DEN            457               125               21        2266
# SEA            525               144               20        2762
# KAN            438                91                8        1929
#
#      rush_yards_per_attempt  turnovers  yards  yards_from_penalties  \
# TAM                     4.6         19   5362                   837
# DET                     3.7         39   4949                   939
# DEN                     5.0         27   6090                   877
# SEA                     5.3         14   6012                  1009
# KAN                     4.4         27   4851                   667
#
#      yards_per_play
# TAM             5.6
# DET             5.1
# DEN             5.8
# SEA             5.9
# KAN             4.8
#
# [5 rows x 22 columns]

# %%
# Pre-processing
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.39754098, 0.24390244, 0.45833333, ..., 0.45873911, 0.43978495,
#         0.6       ],
#        [0.4057377 , 0.48780488, 0.625     , ..., 0.35289595, 0.54946237,
#         0.43333333],
#        [0.68032787, 0.58536585, 0.20833333, ..., 0.6453101 , 0.4827957 ,
#         0.66666667],
#        ...,
#        [0.30327869, 0.82926829, 0.375     , ..., 0.21937468, 0.5       ,
#         0.3       ],
#        [0.68442623, 0.3902439 , 0.29166667, ..., 0.62916453, 0.48494624,
#         0.73333333],
#        [0.6147541 , 0.41463415, 0.16666667, ..., 0.65581753, 0.59892473,
#         0.8       ]])

# %%
# Model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {rf.score(X_train, y_train)}")
print(f"Testing Data Score: {rf.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.16666666666666666

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.05884852390299705, 'pass_first_downs'),
#  (0.051807463766649624, 'pass_attempts'),
#  (0.0515756887449754, 'pass_yards'),
#  (0.04878288397830527, 'offensive_simple_rating_system'),
#  (0.04857969953930085, 'percent_drives_with_turnovers'),
#  (0.048293566676092324, 'losses'),
#  (0.047960139409489795, 'pass_touchdowns'),
#  (0.04719077847136706, 'plays'),
#  (0.04577468629848081, 'abbreviation'),
#  (0.04559811729394448, 'pass_net_yards_per_attempt'),
#  (0.04485265413897792, 'margin_of_victory'),
#  (0.04483011371708427, 'percent_drives_with_points'),
#  (0.04398879518129847, 'first_downs_from_penalties'),
#  (0.04396490779208219, 'games_played'),
#  (0.04304523114141449, 'defensive_simple_rating_system'),
#  (0.042622847430854545, 'penalties'),
#  (0.042313364823486445, 'interceptions'),
#  (0.04195597024901398, 'fumbles'),
#  (0.04186525178794903, 'pass_completions'),
#  (0.040819566667761924, 'name'),
#  (0.037713746343144144, 'points_against'),
#  (0.037616002645329896, 'first_downs')]

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [250, 300, 350],
              'max_depth': [125, 150, 175]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=125, n_estimators=250 .................................
# C:\Users\TreyG\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... max_depth=125, n_estimators=250, score=0.149, total=   0.4s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.172, total=   0.4s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.221, total=   0.4s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.186, total=   0.4s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.244, total=   0.4s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.138, total=   0.5s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.172, total=   0.4s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.244, total=   0.5s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.163, total=   0.5s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.244, total=   0.4s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.149, total=   0.6s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.195, total=   0.6s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.233, total=   0.6s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.163, total=   0.6s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.244, total=   0.6s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.172, total=   0.4s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.172, total=   0.4s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.233, total=   0.4s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.186, total=   0.5s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.256, total=   0.4s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.126, total=   0.5s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.184, total=   0.5s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.209, total=   0.4s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.174, total=   0.5s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.256, total=   0.5s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.161, total=   0.5s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.172, total=   0.5s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.209, total=   0.5s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.209, total=   0.5s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.256, total=   0.5s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.149, total=   0.4s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.161, total=   0.4s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.221, total=   0.4s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.198, total=   0.4s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.221, total=   0.4s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.126, total=   0.5s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.172, total=   0.4s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.221, total=   0.5s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.186, total=   0.5s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.256, total=   0.5s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.138, total=   0.5s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.195, total=   0.5s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.244, total=   0.5s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.174, total=   0.5s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.209, total=   0.5s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   21.2s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [125, 150, 175],
#                          'n_estimators': [250, 300, 350]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 150, 'n_estimators': 250}
# 0.20384923817161188

# %%
# Training score:
grid.score(X_train, y_train)
# Out:
# 1.0

# %%
# Testing score:
grid.score(X_test, y_test)
# Out:
# 0.1597222222222222

# %%
# Make prediction and save to variable for report.
predictions = grid.predict(X_test)

# %%
# Print Classification Report.
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         4
#            3       0.00      0.00      0.00         3
#            4       0.29      0.29      0.29        14
#            5       0.25      0.13      0.17        15
#            6       0.08      0.11      0.09         9
#            7       0.10      0.30      0.15        10
#            8       0.00      0.00      0.00        16
#            9       0.15      0.12      0.13        17
#           10       0.24      0.44      0.31        16
#           11       0.11      0.06      0.08        16
#           12       0.43      0.27      0.33        11
#           13       0.00      0.00      0.00         9
#           14       0.00      0.00      0.00         1
#           15       0.00      0.00      0.00         1
#
#     accuracy                           0.16       144
#    macro avg       0.11      0.11      0.10       144
# weighted avg       0.16      0.16      0.15       144
# C:\Users\TreyG\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %matplotlib notebook
from yellowbrick.classifier import ClassificationReport
viz = ClassificationReport(RandomForestClassifier())
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.finalize()
# Out:
# C:\Users\TreyG\anaconda3\lib\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\TreyG\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-198-7c97d1d1afe0> in <module>
#       3 viz = ClassificationReport(RandomForestClassifier())
#       4 viz.fit(X_train, y_train)
# ----> 5 viz.score(X_test, y_test)
#       6 viz.finalize()
#
# ~\anaconda3\lib\site-packages\yellowbrick\classifier\classification_report.py in score(self, X, y)
#     200             self.scores_.pop("support")
#     201
# --> 202         self.draw()
#     203         return self.score_
#     204
#
# ~\anaconda3\lib\site-packages\yellowbrick\classifier\classification_report.py in draw(self)
#     213         for idx, cls in enumerate(self.classes_):
#     214             for jdx, metric in enumerate(self._displayed_scores):
# --> 215                 cr_display[idx, jdx] = self.scores_[metric][cls]
#     216
#     217         # Set up the dimensions of the pcolormesh
#
# KeyError: 15

# %%
from yellowbrick.model_selection import FeatureImportances
from yellowbrick.style import set_palette
from yellowbrick.features import RadViz
set_palette('yellowbrick')
viz = FeatureImportances(rf, size=(500, 500))
viz.fit(X_train, y_train)
# Out:
# C:\Users\TreyG\anaconda3\lib\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\TreyG\anaconda3\lib\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# FeatureImportances(absolute=False,
#                    ax=<matplotlib.axes._subplots.AxesSubplot object at 0x0000023F777FE748>,
#                    colormap=None, colors=None, is_fitted='auto', labels=None,
#                    model=None, relative=True, stack=False, xlabel=None)

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'randomforest.sav'
joblib.dump(rf, 'randomforest.sav')
# Out:
# ['randomforest.sav']
